# %% [markdown]
# <center> <h1>Hypothyroid Mock Project</h1></center>

# %% [markdown]
# ## 1: Business Understandng

# %% [markdown]
# ### 1.1 Business Overview
# Hypothyroidism is a medical condition where the thyroid gland fails to produce enough thyroid hormones, leading to symptoms like fatigue, weight gain, and depression. Common factors affecting hypothyroidism in the real world include iodine deficiency, autoimmune diseases (like Hashimoto's thyroiditis), certain medications, and radiation therapy.The frequency of hypothyroidism, goiters, and thyroid nodules increases with age. Hypothyroidism is most prevalent in elderly populations, with 2-20% of older age groups having some form of hypothyroidism. A Framingham study found hypothyroidism in 5.9% of women and 2.4% of men older than 60 years.Kenya Medical Research Institute aim to identify patterns and relations between demographic factors, medical history, and thyroid function test results. By analyzing these patterns, they hope to improve diagnostic accuracy, tailor treatments more effectively, and enhance the overall understanding of hypothyroidis management.

# %% [markdown]
# ### 1.2 Problem Statement
# The Kenya Medical Research Institute is committed to improving the lives of patients with hypothyroidism. We aim to understand how different demographic and clinical factors affect the management and outcomes of this condition.

# %% [markdown]
# ### 1.3 Objectives
# #### Main objective
# To create a machine learning model that can predict if a patient is at high risk of being diagnosed with hypothyrodism.
#
# #### Specific objectives
# To determine which risk factors heavily predipose one to getting the condition
#
# To determine which gender is greatly affected by the condition
#
# To determine what age group is greatly affected wiith the condition
#
# To establish a diagnosing criteria for the condition

# %% [markdown]
# ### 1.4 Succuess Criteria
# Success Criteria for the Hypothyroidism Project:
#
# Improved Diagnostic Accuracy: Achieving a higher rate of correct diagnoses by using patterns identified in the data.
#
# Evaluation Tools: Confusion matrix, accuracy score.
# Personalized Treatment Plans: Developing tailored treatment strategies that lead to better patient outcomes and satisfaction.
#
# Evaluation Tools: Patient surveys, treatment adherence rates.
# Increased Sensitivity and Specificity: Enhancing the ability to correctly identify patients with hypothyroidism (sensitivity) and those without it (specificity).
#
# Evaluation Tools: ROC-AUC curve, precision-recall curve, sensitivity (recall) and specificity metrics.
# Reduction in Misdiagnosis Rates: Lowering the instances of patients being wrongly diagnosed with or without hypothyroidism.
#
# Evaluation Tools: False positive rate, false negative rate, misdiagnosis rate.
# Patient Health Outcomes: Observing measurable improvements in patient health and quality of life following the implementation of data-driven treatment plans.
#
# Evaluation Tools: Health outcome surveys, follow-up clinical assessments, Quality of Life (QoL) scores.
# Clinical Adoption: Encouraging healthcare providers to integrate the project's findings into regular clinical practice.
#
# Evaluation Tools: Adoption rate statistics, feedback from healthcare providers, number of clinics implementing the new protocols.
# Patient Engagement and Feedback: Gathering positive feedback from patients on their treatment experiences and perceived improvements in care.
#
# Evaluation Tools: Patient satisfaction surveys, Net Promoter Score (NPS), patient testimonials.
# Research Publications: Producing high-quality research papers that contribute to the medical community's understanding of hypothyroidism.
#
# Evaluation Tools: Number of publications, citation counts, peer review feedback.

# %% [markdown]
# ## 2.1 Data Understanding
# Description of each feature in the dataset:
#
# status: Indicates if the patient is hypothyroid.
#
# age : Age of the patient.
#
# sex: Gender of the patient (M/F).
#
# on_thyroxine: Indicates if the patient is on thyroxine medication.
#
# query_on_thyroxine: Query if the patient is on thyroxine.
#
# on_antithyroid_medication: Indicates if the patient is on antithyroid medication.
#
# thyroid_surgery: Indicates if the patient has had thyroid surgery.
#
# query_hypothyroid: Query if the patient is hypothyroid.
#
# query_hyperthyroid: Query if the patient is hyperthyroid.
#
# pregnant: Indicates if the patient is pregnant.
#
# sick: Indicates if the patient is sick.
#
# tumor: Indicates if the patient has a tumor.
#
# lithium: Indicates if the patient is on lithium.
#
# goitre: Indicates if the patient has a goitre.
#
# TSH_measured: Indicates whether TSH)level has been measured. Values are 'y' (yes) or 'n' (no).
#
# TSH: The actual measured value of the TSH level if TSH_measured is 'y'. e
#
# T3_measured: Indicates whether T3 level has been measured.
#
# T3: The actual measured value of the T3 level if T3_measurd is 'y'.
#
# TT4_measured: Indicates whether the TT4 level has been measured. Values are 'y' (yes) or 'n' (no).
#
# TT4: The actual measured value of the TT4 level if TT4_measured is 'y'.
#
# T4U_measured: Indicates whether the Thyroxine Uptake (T4U) level has been measured. Values are 'y' (yes) or 'n' (no).
#
# T4U: The actual measured value of the T4U level if T4U_measured is 'y'.
#
# FTI: The actual measured value of the FTI if FTI_measured is 'y'.
#
# TBG_measured: Indicates whether the Thyroxine-Binding Globulin (TBG) level has been measured. Values are 'y' (yes) or 'n' (no).
#
# TBG: The actual measured value of the TBG level if TBG_measured is 'y'.
#
# FTI: The actual measured value of the FTI if FTI_measured is 'y'.
#
# TBG_measured: Indicates whether the Thyroxine-Binding Globulin (TBG) level has been measured. Values are 'y' (yes) or 'n' (no).
#
# TBG: The actual measured value of the TBG level if TBG_measured is 'y'.

# %%
# importing necessary libraries
import pandas as pd
import pprint
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class uncleanAnalysis:
    def __init__(self, path):
      # load dataset
        self.df = pd.read_csv(path)

    def basic_info(self):
        print("# First five rows of the dataset")
        # first 5 entries
        pprint.pp(self.df.head())

        # shape of hypothyroid dataset
        print("\n# Shape of the dataset")
        pprint.pp(self.df.shape)

        # dataset columns
        print("\n# Columns of the dataset")
        print(self.df.columns)

        # first 10 unique values within the columns
        print("\n# Distinct categories or values in the dataset")
        for column in self.df.columns:
            pprint.pp(f"{column}: {self.df[column].unique()[:10]}")

        # More info abt the dataset
        print("\n# Info of the dataset")
        pprint.pp(self.df.info())

        # mean, percentiles, count, etc
        print("\n# Statistical summary before cleaning")
        pprint.pp(self.df.describe())

        # null values
        print("\n# Checking for missing values")
        pprint.pp(self.df.isnull().sum())

        # column data typpes
        print("\n# Data types of columns")
        pprint.pp(self.df.dtypes)

# import file here
path = "sample_data/hypothyroid.csv"

# Assign class to variable 'analysis'
analysis = uncleanAnalysis(path)

# Call the class
analysis.basic_info()
# Out:
# # First five rows of the dataset
#         status age sex on_thyroxine query_on_thyroxine  \
# 0  hypothyroid  72   M            f                  f
# 1  hypothyroid  15   F            t                  f
# 2  hypothyroid  24   M            f                  f
# 3  hypothyroid  24   F            f                  f
# 4  hypothyroid  77   M            f                  f
#
#   on_antithyroid_medication thyroid_surgery query_hypothyroid  \
# 0                         f               f                 f
# 1                         f               f                 f
# 2                         f               f                 f
# 3                         f               f                 f
# 4                         f               f                 f
#
#   query_hyperthyroid pregnant  ... T3_measured   T3 TT4_measured TT4  \
# 0                  f        f  ...           y  0.6            y  15
# 1                  f        f  ...           y  1.7            y  19
# ...

# %%
class cleanAnalysis(uncleanAnalysis):
    def __init__(self, path):
        super().__init__(path)
        self.clean_data()

    def clean_data(self):
        # Fill "?" with modal values
        for column in self.df.columns:
            mode = self.df[column].mode()[0]
            self.df[column] = self.df[column].replace('?', mode)

        # Define a function to clean numeric values
        def clean_numeric(x):
            return re.sub(r'[^\d.]+', '', str(x))

        # Clean and convert appropriate columns to numeric
        numeric_cols = ['age', 'T3', 'TT4', 'T4U', 'FTI']
        for col in numeric_cols:
            self.df[col] = self.df[col].map(clean_numeric)
            self.df[col] = pd.to_numeric(self.df[col], errors='ignore')

        # Convert binary columns to boolean
        bool_cols = [
            'on_thyroxine', 'query_on_thyroxine', 'on_antithyroid_medication',
            'thyroid_surgery', 'query_hypothyroid', 'query_hyperthyroid',
            'pregnant', 'sick', 'tumor', 'lithium', 'goitre', 'TSH_measured',
            'T3_measured', 'TT4_measured', 'T4U_measured', 'FTI_measured', 'TBG_measured'
        ]
        for col in bool_cols:
            self.df[col] = self.df[col].map({'t': True, 'f': False, 'y': True, 'n': False})

        # Map M and F to Male and Female
        self.df['sex'] = self.df['sex'].map({'M': 'Male', 'F': 'Female', 'm': 'Male', 'f': 'Female'})
        
        # Fill remaining missing values
        for col in self.df.columns:
            if self.df[col].dtype == "object":
                self.df[col].fillna(self.df[col].mode()[0], inplace=True)
            else:
                self.df[col].fillna(self.df[col].mean(), inplace=True)

        # Print to verify the cleaning steps
        print("\n# Data types after cleaning")
        pprint.pprint(self.df.dtypes)

        print("\n# Checking for missing values after cleaning")
        pprint.pprint(self.df.isnull().sum())


# Assign class to variable 'clean_analysis'
clean_analysis = cleanAnalysis(path)

# Call the class to perform cleaning and basic info
clean_analysis.basic_info()
# Out:
# # Data types after cleaning
# status                        object
# age                          float64
# sex                           object
# on_thyroxine                    bool
# query_on_thyroxine              bool
# on_antithyroid_medication       bool
# thyroid_surgery                 bool
# query_hypothyroid               bool
# query_hyperthyroid              bool
# pregnant                        bool
# sick                            bool
# tumor                           bool
# lithium                         bool
# goitre                          bool
# TSH_measured                    bool
# TSH                           object
# T3_measured                     bool
# T3                           float64
# TT4_measured                    bool
# TT4                          float64
# T4U_measured                    bool
# T4U                          float64
# FTI_measured                    bool
# FTI                          float64
# ...

# %%
clean_analysis.df.to_csv('hypothyroid.csv')

# %%
class visualizationAnalysis(cleanAnalysis):
    def __init__(self, path):
        super().__init__(path)
        self.visualize_data()

    def visualize_data(self):
        # Select numerical and categorical columns
        numerical_values = self.df.select_dtypes(include=['int64', 'float64'])
        categorical_values = self.df.select_dtypes(include=['object'])

        # Count plots for categorical values
        for col in categorical_values.columns:
            plt.figure(figsize=(10, 6))
            ax = sns.countplot(data=self.df, x=col, palette='viridis')
            ax.set_title(f'Count Plot: {col}')
            plt.show()

        # Bar plots for categorical values
        for col in categorical_values.columns:
            plt.figure(figsize=(10, 6))
            ax = sns.barplot(data=self.df, x=col, y=numerical_values.columns[0], palette='viridis')
            ax.set_title(f'Bar Plot: {col}')
            plt.show()

        # Scatter plots for numerical values
        for col in numerical_values.columns:
            if col != 'age':
                plt.figure(figsize=(10, 6))
                sns.scatterplot(data=self.df, x='age', y=col, hue='status', palette='viridis')
                plt.title(f'Scatter Plot: Age vs {col}')
                plt.show()

        # Box plots for numerical values
        for col in numerical_values.columns:
            plt.figure(figsize=(10, 6))
            sns.boxplot(data=self.df, y=col, palette='viridis')
            plt.title(f'Box Plot: {col}')
            plt.show()

        # Heatmap for correlation of numerical values
        plt.figure(figsize=(12, 8))
        sns.heatmap(numerical_values.corr(), annot=True, cmap='viridis')
        plt.title('Correlation Heatmap')
        plt.show()

# Assign class to variable 'visualization_analysis'
visualization_analysis = visualizationAnalysis(path)
# Out:
# # Data types after cleaning
# status                        object
# age                          float64
# sex                           object
# on_thyroxine                    bool
# query_on_thyroxine              bool
# on_antithyroid_medication       bool
# thyroid_surgery                 bool
# query_hypothyroid               bool
# query_hyperthyroid              bool
# pregnant                        bool
# sick                            bool
# tumor                           bool
# lithium                         bool
# goitre                          bool
# TSH_measured                    bool
# TSH                           object
# T3_measured                     bool
# T3                           float64
# TT4_measured                    bool
# TT4                          float64
# T4U_measured                    bool
# T4U                          float64
# FTI_measured                    bool
# FTI                          float64
# ...
